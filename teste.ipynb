# %%
import pandas as pd

# %%
pd.read_csv("datasets/raw_data/premier_league/standings.csv")
# Out:
#         season    Rk            Squad    MP     W     D     L    GF     GA  \
# 0    2014-2015   1.0          Chelsea  38.0  26.0   9.0   3.0  73.0   32.0
# 1    2014-2015   2.0  Manchester City  38.0  24.0   7.0   7.0  83.0   38.0
# 2    2014-2015   3.0          Arsenal  38.0  22.0   9.0   7.0  71.0   36.0
# 3    2014-2015   4.0   Manchester Utd  38.0  20.0  10.0   8.0  62.0   37.0
# 4    2014-2015   5.0        Tottenham  38.0  19.0   7.0  12.0  58.0   53.0
# ..         ...   ...              ...   ...   ...   ...   ...   ...    ...
# 195  2023-2024  16.0        Brentford  36.0   9.0   9.0  18.0  52.0   60.0
# 196  2023-2024  17.0  Nott'ham Forest  36.0   8.0   9.0  19.0  45.0   63.0
# 197  2023-2024  18.0       Luton Town  36.0   6.0   8.0  22.0  49.0   78.0
# 198  2023-2024  19.0          Burnley  36.0   5.0   9.0  22.0  39.0   74.0
# 199  2023-2024  20.0    Sheffield Utd  36.0   3.0   7.0  26.0  35.0  100.0
#
# ...
