# %%
import pandas as pd
import requests
from io import StringIO

# %%
csv = pd.read_csv('datasets/raw_data/brasileirao/match_history.csv')

# %%
csv[csv['season'] == 2015]
# Out:
#       season date time comp round  day venue result   gf   ga  ... poss.1  \
# 796     2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...    NaN
# 797     2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...    NaN
# 798     2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...    NaN
# 799     2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...    NaN
# 800     2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...    NaN
# ...      ...  ...  ...  ...   ...  ...   ...    ...  ...  ...  ...    ...
# 1621    2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...   52.0
# 1622    2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...   56.0
# 1623    2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...   49.0
# 1624    2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...   40.0
# 1625    2015  NaN  NaN  NaN   NaN  NaN   NaN    NaN  NaN  NaN  ...   52.0
#
#       attendance.1  captain.1  formation.1  \
# 796        35000.0        NaN          NaN
# 797        15000.0        NaN          NaN
# 798        50000.0        NaN          NaN
# 799            NaN        NaN          NaN
# 800            NaN        NaN          NaN
# ...            ...        ...          ...
# 1621        9679.0        NaN      4-2-2-2
# 1622        8453.0        NaN      4-2-3-1
# 1623        7026.0        NaN      4-3-1-2
# 1624       24933.0        NaN      4-2-3-1
# 1625        5979.0        NaN      4-3-2-1
#
#                                referee.1 match report.1  \
# 796                     Patricio Loustau   Match Report
# 797                        Darío Ubríaco   Match Report
# 798              Ricardo Marques Ribeiro   Match Report
# 799                          Carlos Vera   Match Report
# 800                       Julio Bascuñán   Match Report
# ...                                  ...            ...
# 1621                        Wagner Reway   Match Report
# 1622             Luiz Flávio de Oliveira   Match Report
# 1623  Marcelo Aparecido Ribeiro De Souza   Match Report
# 1624              Rodolpho Toski Marques   Match Report
# 1625                       Raphael Claus   Match Report
#
#                           notes.1 sh.1 sot.1  saves.1
# 796                    Leg 1 of 2  NaN   NaN      NaN
# 797   Leg 2 of 2; Corinthians won  NaN   NaN      NaN
# 798                           NaN  NaN   NaN      NaN
# 799                           NaN  NaN   NaN      NaN
# 800                           NaN  NaN   NaN      NaN
# ...                           ...  ...   ...      ...
# 1621                          NaN  NaN   NaN      NaN
# 1622                          NaN  NaN   NaN      NaN
# 1623                          NaN  NaN   NaN      NaN
# 1624                          NaN  NaN   NaN      NaN
# 1625                          NaN  NaN   NaN      NaN
#
# [830 rows x 45 columns]

# %%
csv['season'] = csv['season'].apply(str)

# %%
csv['season']
# Out:
# 0      2014
# 1      2014
# 2      2014
# 3      2014
# 4      2014
#        ...
# 215    2024
# 216    2024
# 217    2024
# 218    2024
# 219    2024
# Name: season, Length: 220, dtype: object
