# %%
import pandas as pd
import requests
from io import StringIO

# %%
csv = pd.read_csv('datasets/raw_data/brasileirao/match_history.csv')

# %%
webFile = pd.read_html(f"https://fbref.com/en/squads/2091c619/2024/matchlogs/all_comps/passing/Athletico-Paranaense-Match-Logs-All-Competitions")[0]

# %%
webFile.columns = webFile.columns.droplevel()

# %%
colunas_duplicadas = webFile.columns[webFile.columns.duplicated()].tolist()

novos_nomes = {}
contador = {}
for coluna in colunas_duplicadas:
    if coluna in contador:
        contador[coluna] += 1
    else:
        contador[coluna] = 2
    novos_nomes[coluna] = f"{coluna}_{contador[coluna]}"

# %%
webFile.loc[:,~webFile.columns.duplicated()]
# Out:
#           Date   Time          Comp        Round  Day Venue Result   GF   GA  \
# 0   2024-04-02  20:30  Sudamericana  Group stage  Tue  Away      W  4.0  1.0
# 1   2024-04-09  21:30  Sudamericana  Group stage  Tue  Home      W  6.0  0.0
# 2   2024-04-14  16:00       Série A  Matchweek 1  Sun  Home      W  4.0  0.0
# 3   2024-04-17  19:00       Série A  Matchweek 2  Wed  Away      L  0.0  2.0
# 4   2024-04-21  16:00       Série A  Matchweek 3  Sun  Home      W  1.0  0.0
# 5   2024-04-24  19:00  Sudamericana  Group stage  Wed  Away      W  1.0  0.0
# 6   2024-04-28  18:30       Série A  Matchweek 4  Sun  Away      D  1.0  1.0
# 7   2024-05-05  16:00       Série A  Matchweek 5  Sun  Home      W  1.0  0.0
# 8   2024-05-08  18:00  Sudamericana  Group stage  Wed  Away      W  5.0  1.0
# 9   2024-05-12  16:00       Série A  Matchweek 6  Sun  Away      W  2.0  0.0
# 10         NaN    NaN           NaN          NaN  NaN   NaN     --  NaN  NaN
#
# ...
